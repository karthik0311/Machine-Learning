# %%
# !unzip "/content/drive/My Drive/Dog Vision/dog-breed-identification.zip" -d "/content/drive/My Drive/Dog Vision/"
# Out:
# Archive:  /content/drive/My Drive/Dog Vision/dog-breed-identification.zip
# replace /content/drive/My Drive/Dog Vision/labels.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/My Drive/Dog Vision/labels.csv
# replace /content/drive/My Drive/Dog Vision/sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/My Drive/Dog Vision/sample_submission.csv
# replace /content/drive/My Drive/Dog Vision/test/000621fb3cbb32d8935728e48679680e.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/My Drive/Dog Vision/test/000621fb3cbb32d8935728e48679680e.jpg
# replace /content/drive/My Drive/Dog Vision/test/00102ee9d8eb90812350685311fe5890.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:
